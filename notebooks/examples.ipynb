# %%
import figur
# Out:
# Better speed can be achieved with apex installed from https://www.github.com/nvidia/apex.
# 2019-02-26 18:48:47,763 loading file /home/severin/.figur/models/figurenerkennung-0.0.1.pt

# %%
text = "Der Gärtner entfernte sich eilig, und Eduard folgte bald. "\
       "Eduard versicherte seine Gattin auf die anmutigste Weise der lebhaftesten Dankbarkeit."

# %%
tagged = figur.tag(text)

# %%
tagged
# Out:
#     SentenceId         Token      Tag
# 0            0           Der        _
# 1            0       Gärtner  AppTdfW
# 2            0     entfernte        _
# 3            0          sich     pron
# 4            0        eilig,        _
# 5            0           und        _
# 6            0        Eduard     Core
# 7            0        folgte        _
# 8            0         bald.        _
# 9            1        Eduard     Core
# 10           1   versicherte        _
# 11           1         seine     pron
# 12           1        Gattin  AppTdfW
# 13           1           auf        _
# 14           1           die        _
# 15           1    anmutigste        _
# 16           1         Weise        _
# 17           1           der        _
# 18           1  lebhaftesten        _
# 19           1  Dankbarkeit.        _
